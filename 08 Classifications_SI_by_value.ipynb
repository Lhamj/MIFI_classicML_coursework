# %% [markdown]
# # Курсовая работа. Классическое машинное обучение
#
# ## Классификация: превышает ли значение SI значение 8

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['CUDA_VISIBLE_DEVICES'] = '-1' 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'  
import sys
sys.path.append('./')
# Импортируем методы из common_methods.py
from common_methods import *

# %%
train_and_compare_classifications('./data/SI_8_df.csv')
# Out:
#                  Модель Метод редукции  \
# 8              AdaBoost    NoReduction
# 18             AdaBoost            PCA
# 28             AdaBoost           UMAP
# 3              CatBoost    NoReduction
# 13             CatBoost            PCA
# 23             CatBoost           UMAP
# 1         Decision tree    NoReduction
# 11        Decision tree            PCA
# 21        Decision tree           UMAP
# 7     Gradient boosting    NoReduction
# 17    Gradient boosting            PCA
# 27    Gradient boosting           UMAP
# 0   Logistic regression    NoReduction
# 10  Logistic regression            PCA
# 20  Logistic regression           UMAP
# 4                   MLP    NoReduction
# 14                  MLP            PCA
# 24                  MLP           UMAP
# 2         Random forest    NoReduction
# 12        Random forest            PCA
# 22        Random forest           UMAP
# 6                   SGD    NoReduction
# 16                  SGD            PCA
# 26                  SGD           UMAP
# 5                   SVC    NoReduction
# 15                  SVC            PCA
# 25                  SVC           UMAP
# 9               XGBoost    NoReduction
# 19              XGBoost            PCA
# 29              XGBoost           UMAP
#
#                                      Лучшие параметры  Accuracy  Precision  \
# 8         {'learning_rate': 0.01, 'n_estimators': 50}  0.735294   0.000000
# 18        {'learning_rate': 0.01, 'n_estimators': 50}  0.735294   0.000000
# 28        {'learning_rate': 0.1, 'n_estimators': 100}  0.741176   1.000000
# 3   {'depth': 6, 'iterations': 500, 'learning_rate...  0.723529   0.437500
# 13  {'depth': 8, 'iterations': 100, 'learning_rate...  0.735294   0.500000
# 23  {'depth': 6, 'iterations': 100, 'learning_rate...  0.741176   0.666667
# 1            {'criterion': 'entropy', 'max_depth': 3}  0.705882   0.400000
# 11           {'criterion': 'entropy', 'max_depth': 3}  0.741176   0.538462
# 21           {'criterion': 'entropy', 'max_depth': 3}  0.735294   0.500000
# 7   {'learning_rate': 0.01, 'max_depth': 5, 'n_est...  0.735294   0.500000
# 17  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...  0.747059   1.000000
# 27  {'learning_rate': 0.01, 'max_depth': 3, 'n_est...  0.741176   1.000000
# 0                       {'C': 0.1, 'solver': 'lbfgs'}  0.717647   0.434783
# 10                      {'C': 0.1, 'solver': 'lbfgs'}  0.741176   1.000000
# 20                    {'C': 1, 'solver': 'liblinear'}  0.717647   0.363636
# 4   {'activation': 'relu', 'hidden_layer_sizes': (...  0.676471   0.368421
# 14  {'activation': 'relu', 'hidden_layer_sizes': (...  0.670588   0.310345
# 24  {'activation': 'tanh', 'hidden_layer_sizes': (...  0.729412   0.428571
# 2   {'max_depth': 5, 'max_features': None, 'n_esti...  0.741176   0.533333
# 12  {'max_depth': 5, 'max_features': 'sqrt', 'n_es...  0.723529   0.375000
# 22  {'max_depth': 5, 'max_features': None, 'n_esti...  0.694118   0.294118
# 6   {'alpha': 0.01, 'loss': 'hinge', 'max_iter': 1...  0.688235   0.346154
# 16  {'alpha': 0.01, 'loss': 'hinge', 'max_iter': 1...  0.735294   0.000000
# 26  {'alpha': 0.0001, 'loss': 'log_loss', 'max_ite...  0.735294   0.000000
# 5                           {'C': 1, 'kernel': 'rbf'}  0.729412   0.444444
# 15                          {'C': 1, 'kernel': 'rbf'}  0.735294   0.500000
# 25                         {'C': 10, 'kernel': 'rbf'}  0.717647   0.363636
# 9   {'colsample_bytree': 0.8, 'learning_rate': 0.0...  0.735294   0.500000
# 19  {'colsample_bytree': 0.9, 'learning_rate': 0.0...  0.729412   0.428571
# 29  {'colsample_bytree': 1.0, 'learning_rate': 0.0...  0.741176   1.000000
#
#       Recall        F1   ROC AUC
# 8   0.000000  0.000000  0.500000
# 18  0.000000  0.000000  0.500000
# 28  0.022222  0.043478  0.539022
# 3   0.155556  0.229508  0.583644
# 13  0.066667  0.117647  0.593422
# 23  0.044444  0.083333  0.519111
# 1   0.222222  0.285714  0.516889
# 11  0.155556  0.241379  0.614311
# 21  0.044444  0.081633  0.483111
# 7   0.066667  0.117647  0.550578
# 17  0.044444  0.085106  0.640089
# 27  0.022222  0.043478  0.506222
# 0   0.222222  0.294118  0.578044
# 10  0.022222  0.043478  0.558578
# 20  0.088889  0.142857  0.568356
# 4   0.311111  0.337349  0.587022
# 14  0.200000  0.243243  0.600356
# 24  0.066667  0.115385  0.538844
# 2   0.177778  0.266667  0.586044
# 12  0.066667  0.113208  0.577956
# 22  0.111111  0.161290  0.495022
# 6   0.200000  0.253521  0.604533
# 16  0.000000  0.000000  0.549689
# 26  0.000000  0.000000  0.523733
# 5   0.088889  0.148148  0.599644
# 15  0.066667  0.117647  0.613156
# 25  0.088889  0.142857  0.529778
# 9   0.044444  0.081633  0.579022
# 19  0.066667  0.115385  0.629333
# 29  0.022222  0.043478  0.505600
