# %% [markdown]
# # Курсовая работа. Классическое машинное обучение
#
# ## Регрессия для CC50

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['CUDA_VISIBLE_DEVICES'] = '-1' 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'  
import sys
sys.path.append('./')
# Импортируем методы из common_methods.py
from common_methods import *

# %%
train_and_compare_regressions('./data/CC50_df.csv', 'CC50')
# Out:
#                  Модель Метод редукции  \
# 4        Bayesian Ridge   No Reduction
# 16       Bayesian Ridge            PCA
# 28       Bayesian Ridge           UMAP
# 10             CatBoost   No Reduction
# 22             CatBoost            PCA
# 34             CatBoost           UMAP
# 5         Decision Tree   No Reduction
# 17        Decision Tree            PCA
# 29        Decision Tree           UMAP
# 3            ElasticNet   No Reduction
# 15           ElasticNet            PCA
# 27           ElasticNet           UMAP
# 7     Gradient Boosting   No Reduction
# 19    Gradient Boosting            PCA
# 31    Gradient Boosting           UMAP
# 9   K-Nearest Neighbors   No Reduction
# 21  K-Nearest Neighbors            PCA
# 33  K-Nearest Neighbors           UMAP
# 2                 Lasso   No Reduction
# 14                Lasso            PCA
# 26                Lasso           UMAP
# 0                Linear   No Reduction
# 12               Linear            PCA
# 24               Linear           UMAP
# 11                  MLP   No Reduction
# 23                  MLP            PCA
# 35                  MLP           UMAP
# 6         Random Forest   No Reduction
# 18        Random Forest            PCA
# 30        Random Forest           UMAP
# 1                 Ridge   No Reduction
# 13                Ridge            PCA
# 25                Ridge           UMAP
# 8                   SVR   No Reduction
# 20                  SVR            PCA
# 32                  SVR           UMAP
#
#                                      Лучшие параметры  Accuracy    Recall  \
# 4   {'alpha_1': 0.0001, 'alpha_2': 1e-06, 'lambda_...  0.647059  0.831461
# 16  {'alpha_1': 1e-06, 'alpha_2': 0.0001, 'lambda_...  0.625668  0.876404
# 28  {'alpha_1': 1e-06, 'alpha_2': 1e-06, 'lambda_1...  0.582888  0.943820
# 10                {'depth': 6, 'learning_rate': 0.01}  0.721925  0.887640
# 22                {'depth': 8, 'learning_rate': 0.01}  0.737968  0.853933
# 34                {'depth': 8, 'learning_rate': 0.01}  0.732620  0.887640
# 5                                    {'max_depth': 5}  0.716578  0.842697
# 17                                   {'max_depth': 3}  0.711230  0.685393
# 29                                   {'max_depth': 3}  0.508021  1.000000
# 3   {'alpha': 1.0, 'l1_ratio': 0.9, 'max_iter': 10...  0.652406  0.831461
# 15  {'alpha': 1.0, 'l1_ratio': 0.1, 'max_iter': 10...  0.598930  0.898876
# 27  {'alpha': 1.0, 'l1_ratio': 0.9, 'max_iter': 10...  0.582888  0.943820
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.727273  0.853933
# 19  {'learning_rate': 0.01, 'max_depth': 10, 'min_...  0.721925  0.842697
# 31  {'learning_rate': 0.01, 'max_depth': 10, 'min_...  0.721925  0.775281
# 9   {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...  0.802139  0.865169
# 21  {'algorithm': 'brute', 'leaf_size': 10, 'n_nei...  0.743316  0.808989
# 33  {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...  0.743316  0.820225
# 2      {'alpha': 10.0, 'max_iter': 1000, 'tol': 0.01}  0.652406  0.853933
# 14     {'alpha': 10.0, 'max_iter': 1000, 'tol': 0.01}  0.609626  0.887640
# 26      {'alpha': 1.0, 'max_iter': 1000, 'tol': 0.01}  0.598930  0.943820
# 0                                             default  0.673797  0.775281
# 12                                            default  0.636364  0.865169
# 24                                            default  0.598930  0.932584
# 11    {'hidden_layer_sizes': (100,), 'max_iter': 500}  0.705882  0.775281
# 23  {'hidden_layer_sizes': (100, 50), 'max_iter': ...  0.684492  0.752809
# 35  {'hidden_layer_sizes': (100, 50), 'max_iter': ...  0.588235  0.943820
# 6               {'max_depth': 10, 'n_estimators': 50}  0.721925  0.842697
# 18             {'max_depth': 10, 'n_estimators': 100}  0.721925  0.853933
# 30             {'max_depth': 10, 'n_estimators': 100}  0.705882  0.797753
# 1                   {'alpha': 10.0, 'solver': 'saga'}  0.647059  0.741573
# 13                   {'alpha': 10.0, 'solver': 'sag'}  0.636364  0.865169
# 25                  {'alpha': 10.0, 'solver': 'lsqr'}  0.598930  0.943820
# 8                       {'C': 10, 'kernel': 'linear'}  0.679144  0.730337
# 20                      {'C': 10, 'kernel': 'linear'}  0.695187  0.921348
# 32                       {'C': 1, 'kernel': 'linear'}  0.609626  0.696629
#
#      ROC AUC        R2
# 4   0.770924  0.401916
# 16  0.736414  0.196524
# 28  0.660055  0.142484
# 10  0.825384  0.510808
# 22  0.837193  0.507647
# 34  0.808530  0.398181
# 5   0.768000  0.314344
# 17  0.731369  0.237108
# 29  0.625258  0.098317
# 3   0.772988  0.409792
# 15  0.727471  0.201019
# 27  0.662692  0.143816
# 7   0.818849  0.482410
# 19  0.819651  0.482958
# 31  0.800161  0.375165
# 9   0.853474  0.481101
# 21  0.830543  0.424535
# 33  0.799817  0.374621
# 2   0.771497  0.375937
# 14  0.738363  0.200830
# 26  0.669227  0.146995
# 0   0.766567  0.352811
# 12  0.740770  0.188731
# 24  0.671062  0.147181
# 11  0.797638  0.447265
# 23  0.801766  0.455648
# 35  0.681380  0.149817
# 6   0.828250  0.488061
# 18  0.815409  0.475923
# 30  0.801078  0.389921
# 1   0.768631  0.389382
# 13  0.740656  0.189393
# 25  0.670718  0.147356
# 8   0.787205  0.382201
# 20  0.782733  0.087337
# 32  0.711878  0.097264
