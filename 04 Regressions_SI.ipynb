# %% [markdown]
# # Курсовая работа. Классическое машинное обучение
#
# ## Регрессия для SI

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['CUDA_VISIBLE_DEVICES'] = '-1' 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'  
import sys
sys.path.append('./')
# Импортируем методы из common_methods.py
from common_methods import *

# %%
train_and_compare_regressions('./data/SI_df.csv', 'SI')
# Out:
#                  Модель Метод редукции  \
# 4        Bayesian Ridge   No Reduction
# 16       Bayesian Ridge            PCA
# 28       Bayesian Ridge           UMAP
# 10             CatBoost   No Reduction
# 22             CatBoost            PCA
# 34             CatBoost           UMAP
# 5         Decision Tree   No Reduction
# 17        Decision Tree            PCA
# 29        Decision Tree           UMAP
# 3            ElasticNet   No Reduction
# 15           ElasticNet            PCA
# 27           ElasticNet           UMAP
# 7     Gradient Boosting   No Reduction
# 19    Gradient Boosting            PCA
# 31    Gradient Boosting           UMAP
# 9   K-Nearest Neighbors   No Reduction
# 21  K-Nearest Neighbors            PCA
# 33  K-Nearest Neighbors           UMAP
# 2                 Lasso   No Reduction
# 14                Lasso            PCA
# 26                Lasso           UMAP
# 0                Linear   No Reduction
# 12               Linear            PCA
# 24               Linear           UMAP
# 11                  MLP   No Reduction
# 23                  MLP            PCA
# 35                  MLP           UMAP
# 6         Random Forest   No Reduction
# 18        Random Forest            PCA
# 30        Random Forest           UMAP
# 1                 Ridge   No Reduction
# 13                Ridge            PCA
# 25                Ridge           UMAP
# 8                   SVR   No Reduction
# 20                  SVR            PCA
# 32                  SVR           UMAP
#
#                                      Лучшие параметры  Accuracy    Recall  \
# 4   {'alpha_1': 0.0001, 'alpha_2': 1e-06, 'lambda_...  0.576471  1.000000
# 16  {'alpha_1': 1e-06, 'alpha_2': 0.0001, 'lambda_...  0.576471  1.000000
# 28  {'alpha_1': 1e-06, 'alpha_2': 0.0001, 'lambda_...  0.576471  1.000000
# 10                {'depth': 4, 'learning_rate': 0.01}  0.594118  1.000000
# 22                {'depth': 4, 'learning_rate': 0.01}  0.576471  1.000000
# 34                {'depth': 4, 'learning_rate': 0.01}  0.576471  1.000000
# 5                                    {'max_depth': 3}  0.576471  1.000000
# 17                                   {'max_depth': 3}  0.576471  1.000000
# 29                                   {'max_depth': 3}  0.576471  1.000000
# 3   {'alpha': 1.0, 'l1_ratio': 0.1, 'max_iter': 10...  0.570588  0.989796
# 15  {'alpha': 1.0, 'l1_ratio': 0.1, 'max_iter': 10...  0.576471  1.000000
# 27  {'alpha': 1.0, 'l1_ratio': 0.9, 'max_iter': 10...  0.576471  1.000000
# 7   {'learning_rate': 0.01, 'max_depth': 3, 'min_s...  0.576471  1.000000
# 19  {'learning_rate': 0.01, 'max_depth': 10, 'min_...  0.576471  1.000000
# 31  {'learning_rate': 0.01, 'max_depth': 5, 'min_s...  0.576471  1.000000
# 9   {'algorithm': 'ball_tree', 'leaf_size': 30, 'n...  0.570588  0.948980
# 21  {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_n...  0.594118  0.948980
# 33  {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...  0.611765  0.918367
# 2       {'alpha': 1.0, 'max_iter': 1000, 'tol': 0.01}  0.576471  1.000000
# 14      {'alpha': 1.0, 'max_iter': 1000, 'tol': 0.01}  0.576471  1.000000
# 26      {'alpha': 1.0, 'max_iter': 1000, 'tol': 0.01}  0.576471  1.000000
# 0                                             default  0.588235  0.857143
# 12                                            default  0.570588  0.989796
# 24                                            default  0.576471  1.000000
# 11    {'hidden_layer_sizes': (100,), 'max_iter': 500}  0.588235  0.714286
# 23    {'hidden_layer_sizes': (100,), 'max_iter': 500}  0.641176  0.887755
# 35  {'hidden_layer_sizes': (100, 50), 'max_iter': ...  0.576471  1.000000
# 6               {'max_depth': 5, 'n_estimators': 100}  0.576471  1.000000
# 18               {'max_depth': 5, 'n_estimators': 50}  0.576471  1.000000
# 30              {'max_depth': 5, 'n_estimators': 100}  0.576471  1.000000
# 1                   {'alpha': 10.0, 'solver': 'saga'}  0.564706  0.857143
# 13                   {'alpha': 10.0, 'solver': 'sag'}  0.570588  0.989796
# 25             {'alpha': 10.0, 'solver': 'sparse_cg'}  0.576471  1.000000
# 8                          {'C': 10, 'kernel': 'rbf'}  0.635294  0.734694
# 20                         {'C': 10, 'kernel': 'rbf'}  0.647059  0.704082
# 32                         {'C': 10, 'kernel': 'rbf'}  0.641176  0.632653
#
#      ROC AUC        R2
# 4   0.560020  0.033638
# 16  0.500779 -0.024120
# 28  0.598073 -0.005181
# 10  0.675950  0.090690
# 22  0.643637  0.026160
# 34  0.651502  0.017993
# 5   0.585884 -0.055392
# 17  0.555556 -0.057993
# 29  0.501346 -0.098553
# 3   0.575043  0.042001
# 15  0.501346 -0.028147
# 27  0.578373 -0.007290
# 7   0.671981  0.061049
# 19  0.644204  0.017059
# 31  0.604308  0.027574
# 9   0.659722  0.035314
# 21  0.682044  0.083620
# 33  0.625496 -0.016798
# 2   0.522747  0.006047
# 14  0.523030 -0.017282
# 26  0.581633 -0.008246
# 0   0.626205 -0.065692
# 12  0.494260 -0.062966
# 24  0.587443 -0.013549
# 11  0.595451 -0.885112
# 23  0.666029  0.017512
# 35  0.589002 -0.015743
# 6   0.689413  0.067132
# 18  0.624787 -0.023887
# 30  0.600128 -0.022054
# 1   0.604946  0.015029
# 13  0.494118 -0.062216
# 25  0.597506 -0.013491
# 8   0.708121 -0.045140
# 20  0.701885 -0.108666
# 32  0.667800 -0.241948
