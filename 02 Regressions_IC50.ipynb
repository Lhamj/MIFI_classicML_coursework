# %% [markdown]
# # Курсовая работа. Классическое машинное обучение
#
# ## Регрессия для IC50

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['CUDA_VISIBLE_DEVICES'] = '-1' 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'  
import sys
sys.path.append('./')
# Импортируем методы из common_methods.py
from common_methods import *

# %%
train_and_compare_regressions('./data/IC50_df.csv', 'IC50')
# Out:
#                  Модель Метод редукции  \
# 4        Bayesian Ridge   No Reduction
# 16       Bayesian Ridge            PCA
# 28       Bayesian Ridge           UMAP
# 10             CatBoost   No Reduction
# 22             CatBoost            PCA
# 34             CatBoost           UMAP
# 5         Decision Tree   No Reduction
# 17        Decision Tree            PCA
# 29        Decision Tree           UMAP
# 3            ElasticNet   No Reduction
# 15           ElasticNet            PCA
# 27           ElasticNet           UMAP
# 7     Gradient Boosting   No Reduction
# 19    Gradient Boosting            PCA
# 31    Gradient Boosting           UMAP
# 9   K-Nearest Neighbors   No Reduction
# 21  K-Nearest Neighbors            PCA
# 33  K-Nearest Neighbors           UMAP
# 2                 Lasso   No Reduction
# 14                Lasso            PCA
# 26                Lasso           UMAP
# 0                Linear   No Reduction
# 12               Linear            PCA
# 24               Linear           UMAP
# 11                  MLP   No Reduction
# 23                  MLP            PCA
# 35                  MLP           UMAP
# 6         Random Forest   No Reduction
# 18        Random Forest            PCA
# 30        Random Forest           UMAP
# 1                 Ridge   No Reduction
# 13                Ridge            PCA
# 25                Ridge           UMAP
# 8                   SVR   No Reduction
# 20                  SVR            PCA
# 32                  SVR           UMAP
#
#                                      Лучшие параметры  Accuracy    Recall  \
# 4   {'alpha_1': 0.0001, 'alpha_2': 1e-06, 'lambda_...  0.538922  0.975610
# 16  {'alpha_1': 0.0001, 'alpha_2': 1e-06, 'lambda_...  0.556886  0.963415
# 28  {'alpha_1': 0.0001, 'alpha_2': 1e-06, 'lambda_...  0.508982  0.951220
# 10                {'depth': 4, 'learning_rate': 0.01}  0.526946  0.939024
# 22                {'depth': 6, 'learning_rate': 0.01}  0.586826  0.939024
# 34                {'depth': 4, 'learning_rate': 0.01}  0.562874  0.951220
# 5                                    {'max_depth': 3}  0.491018  1.000000
# 17                                   {'max_depth': 3}  0.491018  1.000000
# 29                                   {'max_depth': 3}  0.502994  0.926829
# 3   {'alpha': 1.0, 'l1_ratio': 0.5, 'max_iter': 10...  0.538922  0.975610
# 15  {'alpha': 1.0, 'l1_ratio': 0.5, 'max_iter': 10...  0.556886  0.963415
# 27  {'alpha': 0.1, 'l1_ratio': 0.9, 'max_iter': 10...  0.508982  0.951220
# 7   {'learning_rate': 0.01, 'max_depth': 3, 'min_s...  0.508982  1.000000
# 19  {'learning_rate': 0.01, 'max_depth': 10, 'min_...  0.491018  1.000000
# 31  {'learning_rate': 0.01, 'max_depth': 5, 'min_s...  0.491018  1.000000
# 9   {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_n...  0.628743  0.865854
# 21  {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...  0.604790  0.865854
# 33  {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...  0.604790  0.865854
# 2      {'alpha': 1.0, 'max_iter': 1000, 'tol': 0.001}  0.568862  0.939024
# 14      {'alpha': 1.0, 'max_iter': 1000, 'tol': 0.01}  0.556886  0.951220
# 26      {'alpha': 1.0, 'max_iter': 1000, 'tol': 0.01}  0.508982  0.951220
# 0                                             default  0.508982  0.792683
# 12                                            default  0.550898  0.939024
# 24                                            default  0.508982  0.951220
# 11    {'hidden_layer_sizes': (100,), 'max_iter': 500}  0.640719  0.841463
# 23    {'hidden_layer_sizes': (100,), 'max_iter': 500}  0.568862  0.914634
# 35  {'hidden_layer_sizes': (100, 50), 'max_iter': ...  0.508982  0.951220
# 6                {'max_depth': 5, 'n_estimators': 50}  0.514970  1.000000
# 18              {'max_depth': 5, 'n_estimators': 100}  0.520958  1.000000
# 30              {'max_depth': 5, 'n_estimators': 100}  0.526946  1.000000
# 1                   {'alpha': 10.0, 'solver': 'saga'}  0.580838  0.914634
# 13             {'alpha': 10.0, 'solver': 'sparse_cg'}  0.550898  0.939024
# 25              {'alpha': 1.0, 'solver': 'sparse_cg'}  0.508982  0.951220
# 8                        {'C': 1, 'kernel': 'linear'}  0.616766  0.707317
# 20                      {'C': 10, 'kernel': 'linear'}  0.628743  0.756098
# 32                      {'C': 10, 'kernel': 'linear'}  0.568862  0.670732
#
#      ROC AUC             R2
# 4   0.711693       0.132642
# 16  0.700502       0.096470
# 28  0.609326       0.038119
# 10  0.750574       0.183031
# 22  0.770803       0.177516
# 34  0.707102       0.092121
# 5   0.686657       0.147234
# 17  0.629842      -0.016813
# 29  0.557604      -0.064156
# 3   0.707174       0.130742
# 15  0.699641       0.096520
# 27  0.613773       0.021910
# 7   0.721736       0.123945
# 19  0.764204       0.169278
# 31  0.704735       0.102054
# 9   0.767288       0.155382
# 21  0.747633       0.171950
# 33  0.719871       0.052625
# 2   0.720732       0.131096
# 14  0.704806       0.092979
# 26  0.623529       0.032775
# 0   0.687805 -259393.830072
# 12  0.707102       0.091410
# 24  0.632138       0.013447
# 11  0.759110      -0.196987
# 23  0.720445       0.121119
# 35  0.652080       0.045280
# 6   0.701937       0.130370
# 18  0.725036       0.122203
# 30  0.684075       0.094214
# 1   0.717862       0.107192
# 13  0.706528       0.091729
# 25  0.629412       0.015037
# 8   0.686585       0.006258
# 20  0.708967      -0.015774
# 32  0.608178      -0.091202
